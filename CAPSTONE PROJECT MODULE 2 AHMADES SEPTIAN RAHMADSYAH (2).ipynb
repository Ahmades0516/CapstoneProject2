# %% [markdown]
# ## Latar Belakang
# ---

# %% [markdown]
# TransJakarta adalah sebuah sistem transportasi Bus Rapid Transit (BRT) pertama di Asia Tenggara dan Selatan dengan jalur lintasan terpanjang di dunia (208 km). Sistem BRT ini didesain berdasarkan sistem TransMilenio di Bogota, Kolombia. Terhitung sejak 1 Februari 2004, TransJakarta resmi beroperasi. TransJakarta diputuskan berbentuk Badan Pengelola (BP) TransJakarta berdasarkan Keputusan Gubernur No. 110/2003 dimana: • TransJakarta dikelola secara non-struktural • Menggunakan dana transfer • Anggaran yang fleksibel • Pendapatan yang dapat disetor • Bertanggungjawab langsung ke Gubernur. Pada 4 Mei 2006, Gubernur DKI Sutiyoso mengubah BP TransJakarta menjadi Badan Layanan Umum (BLU) TransJakarta yang adalah Unit Pelaksana Teknis (UPT) di bawah Dinas Perhubungan (Dishub) Provinsi DKI Jakarta. Hal ini diatur dalam Peraturan Gubernur (Pergub) DKI No. 48 Tahun 2006. <br>
# <br>
# Pada 27 Maret 2014, TransJakarta berubah status menjadi bentuk BUMD (Badan Usaha Milik Daerah) dan resmi berganti nama menjadi PT. Transportasi Jakarta. Rencana pembukaan layanan koridor-koridor baru terus berjalan, inovasi-inovasi pun diluncurkan demi kenyamanan para pelanggan.<br>
# <br>
# APRIL 21, 2016. Transjakarta resmi mengoperasikan bus khusus wanita yang berwarna pink dalam rangka memperingati hari kartini. Bus khusus wanita ini dapat ditemui di koridor 1 (Blok M - Kota). Transjakarta juga akan menambah bus khusus wanita di koridor - koridor lainnya<br>
# <br>
# Site Visit Transjakarta: Senior Traveler pertama kali diadakan. Peserta untuk kegiatan pertama kali diikuti oleh 40 lansia dari Panti Werdha Sasana Bina Mulya. Kegiatan ini berjalan rutin setiap minggunya dan diikuti oleh peserta yang berumur 60-70 tahun dari berbagai panti sosial. Harapannya ke depan, Transjakarta tidak hanya nyaman dan aman bagi pelanggan pada umumnya tetapi juga menjadi angkutan umum yang ramah dan mudah bagi anak-anak kecil maupun pelanggan Lansia.

# %% [markdown]
# ## PERMASLAAHAN DAN TUJUAN YANG INGIN DICAPAI

# %% [markdown]
# Dalam konteks pengembangan sistem transportasi Transjakarta, ada beberapa masalah dan tujuan yang ingin dipecahkan. Salah satu fokus utama adalah meningkatkan efektivitas, efisiensi, dan profitabilitas operasional Transjakarta. Untuk mencapai tujuan ini, akan dijelajahi berbagai aspek yang dapat menjadi temuan, seperti : <br>
# A. Corridor Dengan tingkat kesibukan tertinggi <br>
# <br>
# Menganalisa corridor yang memiliki tingkat kesibukan paling tinggi, berdasarkan tap in dan tap out, serta mengidentifikasi jumlah pengguna transjkarta dalam satu hari, dan satu minggu, hal ini bertujuan agar dapat meningkatkan layanan pada corridor transjakarta<br>
# B. Penggunaan type transjakarta berdasarkan kelompok umur <br>
# <br>
# Menganalisa jenis pengguna transjakarta berdasarkan umurnya, dimana dengan analisa kelompok pengguna dapat menjadi bahan acuan dalam pembukaan corridor baru maupun pemberian profit lain kepada pengguna transjakarta<br>
# C. Corridor Dengan jumlah penumpang perempuan terbanyak<br>
# <br>
# Memberikan gambaran terkait dengan pengguna perempuan dalam mode transportasi Transjakarta, sehingga nantinya diharapkan analisa ini menjadi pertimbangan dalam peningkatan fasilitas maupun armada bagi penumpang perempuan
# D. Jenis Payment yang paling banyak digunakan<br>
# <br>
# Menganalisis data transaksi pembayaran, khususnya dalam hal jenis kartu yang paling sering digunakan oleh pengguna Transjakarta. Ini akan membantu Transjakarta dalam mengoptimalkan strategi pembayaran dan meningkatkan pendapatan.

# %%
# Library Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Dataset ini berisi informasi terkait umur, jenis kelamin, asal, tujuan, dan jenis moda transportasi pengguna layanan PT. TransJakarta. Ada 22 kolom di dalam dataset Transjakarta, yaitu:
# |No. | Nama Kolom | Keterangan |
# |----|------------|------------|
# |1.	|transID| Unique transaction id for every transaction|
# |2.	|payCardID| Customers main identifier. The card customers use as a ticket for entrance and exit.|
# |3.	|payCardBank| Customers card bank issuer name|
# |4.	|payCardName| Customers name that is embedded in the card.|
# |5.	|payCardSex| Customers sex that is embedded in the card|
# |6.	|payCardBirthDate| Customers birth year|
# |7.	|corridorID| Corridor ID / Route ID as key for route grouping.|
# |8.	|corridorName| Corridor Name / Route Name contains Start and Finish for each route.|
# |9.	|direction| 0 for Go, 1 for Back. Direction of the route.|
# |10.|tapInStops| Tap In (entrance) Stops ID for identifying stops name|
# |11.|tapInStopsName| Tap In (entrance) Stops Name where customers tap in.|
# |12.|tapInStopsLat| Latitude of Tap In Stops|
# |13.|tapInStopsLon| Longitude of Tap In Stops|
# |14.|stopStartSeq| Sequence of the stops, 1st stop, 2nd stops etc. Related to direction.|
# |15.|tapInTime| Time of tap in. Date and time|
# |16.|tapOutStops| Tap Out (Exit) Stops ID for identifying stops name|
# |17.|tapOutStopsName| Tap out (exit) Stops Name where customers tap out.|
# |18.|tapOutStopsLat| Latitude of Tap Out Stops|
# |19.|tapOutStopsLon| Longitude of Tap Out Stops|
# |20.|stopEndSeq| Sequence of the stops, 1st stop, 2nd stops etc. Related to direction.|
# |21.|tapOutTime| Time of tap out. Date and time|
# |22.|payAmount| The number of what customers pay. Some are free. Some not.|

# %% [markdown]
# ## PENGENALAN DATA
# ---

# %% [markdown]
# Pada tahap ini saya akan melihat info dari dataset Transjakarta, dan kemudian memahami data tersebut

# %%
Tj=pd.read_csv("C:\\Users\\Septian\\Transjakarta (1).csv")
display(Tj.head(),Tj.tail())
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB  180062659848800   emoney      Bajragin Usada   M
# 1  LGXO740D2N47GZ  4885331907664776  dki         Gandi Widodo     F
# 2  DJWR385V2U57TO  4996225095064169  dki         Emong Wastuti    F
# 3  JTUZ800U7C86EH  639099174703      flazz       Surya Wacana     F
# 4  VMLO535V7F95NJ  570928206772      flazz       Embuh Mardhiyah  M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0  2008              5          Matraman Baru - Ancol
# 1  1997              6C         Stasiun Tebet - Karet via Patra Kuningan
# 2  1992              R1A        Pantai Maju - Kota
# 3  1978              11D        Pulo Gebang - Pulo Gadung 2 via PIK
# 4  1982              12         Tanjung Priok - Pluit
#
#    direction tapInStops  ... tapInStopsLon  stopStartSeq            tapInTime  \
# 0  1.0        P00142     ...  106.84402     7             2023-04-03 05:21:44
# ...

# %%
print(f'Jumlah baris dan kolom di dataset TransJakarta adalah {Tj.shape}')
Tj.info()
# Out:
# Jumlah baris dan kolom di dataset TransJakarta adalah (37900, 22)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37900 entries, 0 to 37899
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transID           37900 non-null  object
#  1   payCardID         37900 non-null  int64
#  2   payCardBank       37900 non-null  object
#  3   payCardName       37900 non-null  object
#  4   payCardSex        37900 non-null  object
#  5   payCardBirthDate  37900 non-null  int64
#  6   corridorID        36643 non-null  object
#  7   corridorName      35970 non-null  object
#  8   direction         37900 non-null  float64
#  9   tapInStops        36687 non-null  object
#  10  tapInStopsName    37900 non-null  object
#  11  tapInStopsLat     37900 non-null  float64
#  12  tapInStopsLon     37900 non-null  float64
#  13  stopStartSeq      37900 non-null  int64
#  14  tapInTime         37900 non-null  object
# ...

# %%
pd.set_option('display.max_colwidth', 0)
# Identifikasi jumlah unique, persentase missing value, dan unique pada dataset.
listItem = []
for col in Tj.columns :
    listItem.append( [col, Tj[col].nunique(), Tj[col].unique()])

tabel1Desc = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                     data=listItem)
tabel1Desc
# Out:
#          Column Name  Number of Unique  \
# 0   transID           37900
# 1   payCardID         2000
# 2   payCardBank       6
# 3   payCardName       1993
# 4   payCardSex        2
# 5   payCardBirthDate  67
# 6   corridorID        221
# 7   corridorName      216
# 8   direction         2
# 9   tapInStops        2570
# 10  tapInStopsName    2602
# 11  tapInStopsLat     2587
# 12  tapInStopsLon     2458
# 13  stopStartSeq      67
# 14  tapInTime         37079
# 15  tapOutStops       2230
# 16  tapOutStopsName   2248
# 17  tapOutStopsLat    2237
# 18  tapOutStopsLon    2139
# 19  stopEndSeq        74
# 20  tapOutTime        35908
# 21  payAmount         3
#
# ...

# %%
display(Tj.describe(), Tj.describe(include='object'))
# Out:
#           payCardID  payCardBirthDate     direction  tapInStopsLat  \
# count  3.790000e+04  37900.000000      37900.000000  37900.000000
# mean   4.250060e+17  1990.089314       0.500633     -6.214838
# std    1.321699e+18  13.051482         0.500006      0.057911
# min    6.040368e+10  1946.000000       0.000000     -6.394973
# 25%    1.800442e+14  1982.000000       0.000000     -6.245863
# 50%    3.507947e+15  1990.000000       1.000000     -6.214587
# 75%    4.699023e+15  2001.000000       1.000000     -6.175528
# max    4.997694e+18  2012.000000       1.000000     -6.089429
#
#        tapInStopsLon  stopStartSeq  tapOutStopsLat  tapOutStopsLon  \
# count  37900.000000   37900.000000  36556.000000    36556.000000
# mean   106.841554     13.572480    -6.214651        106.841233
# std    0.060369       12.237623     0.059022        0.060999
# min    106.614730     0.000000     -6.394973        106.614730
# 25%    106.803470     4.000000     -6.247225        106.801750
# ...

# %% [markdown]
# ## CLEANING DATA
# ---

# %% [markdown]
# Cleaning dilakukan dengan melihat missing value, data duplicate, dan anomali data

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          1257
# corridorName        1930
# direction           0
# tapInStops          1213
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %%
round(Tj.isna().sum()/len(Tj)*100, 2)
# Out:
# transID             0.00
# payCardID           0.00
# payCardBank         0.00
# payCardName         0.00
# payCardSex          0.00
# payCardBirthDate    0.00
# corridorID          3.32
# corridorName        5.09
# direction           0.00
# tapInStops          3.20
# tapInStopsName      0.00
# tapInStopsLat       0.00
# tapInStopsLon       0.00
# stopStartSeq        0.00
# tapInTime           0.00
# tapOutStops         6.04
# tapOutStopsName     3.55
# tapOutStopsLat      3.55
# tapOutStopsLon      3.55
# stopEndSeq          3.55
# tapOutTime          3.55
# payAmount           2.66
# dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(Tj[['corridorID','corridorName','tapInStops','tapOutStops','tapOutStopsName','tapOutStopsLat','tapOutStopsLon','stopEndSeq','tapOutTime', 'payAmount']].isna())
# Out:
# <Axes: >

# %% [markdown]
# ## MENGECEK DUPLIKAT

# %%
Tj[Tj.duplicated()]
# Out:
# Empty DataFrame
# Columns: [transID, payCardID, payCardBank, payCardName, payCardSex, payCardBirthDate, corridorID, corridorName, direction, tapInStops, tapInStopsName, tapInStopsLat, tapInStopsLon, stopStartSeq, tapInTime, tapOutStops, tapOutStopsName, tapOutStopsLat, tapOutStopsLon, stopEndSeq, tapOutTime, payAmount]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# -Tidak ditemukan duplikat dalam data

# %% [markdown]
# ## Clearing Data Missing Value corridorID dan corridorName

# %% [markdown]
# sebelum melakukan cleaning kita akan melihat korelasi antara corridorId dan corridorName dan melihat data anomali pada keduanya

# %%
Tj[['corridorID', 'corridorName']]
# Out:
#       corridorID                              corridorName
# 0      5          Matraman Baru - Ancol
# 1      6C         Stasiun Tebet - Karet via Patra Kuningan
# 2      R1A        Pantai Maju - Kota
# 3      11D        Pulo Gebang - Pulo Gadung 2 via PIK
# 4      12         Tanjung Priok - Pluit
# ...    ..                           ...
# 37895  6B         Ragunan - MH Thamrin via Semanggi
# 37896  9N         Pinang Ranti - Pramuka
# 37897  1T         Cibubur - Balai Kota
# 37898  JAK.13     Tanah Abang - Jembatan Lima
# 37899  13         Ciledug - Tendean
#
# [37900 rows x 2 columns]

# %% [markdown]
# Dapat dilihat bahwa setiap corridorName memiliki corridorID sendiri yang berbeda-beda

# %%
#mengecek anomali pada coloum corridorID dan corridorName
anomali= Tj.groupby('corridorID')['corridorName'] .nunique()
anomali[anomali>1]
# Out:
# Series([], Name: corridorName, dtype: int64)

# %%
anomali= Tj.groupby('corridorName')['corridorID'] .nunique()
anomali[anomali>1]
# Out:
# corridorName
# Blok M - Kota                          2
# Kalideres - Bundaran HI via Veteran    2
# Matraman Baru - Ancol                  2
# Pinang Ranti - Pluit                   2
# Pulo Gadung - Monas                    2
# Name: corridorID, dtype: int64

# %% [markdown]
# Pada pengujian anomali diatas didapat bahwa ada 5 corridorName yang memiliki corrirdorID lebih dari 1

# %%
value_TJ = Tj[Tj["corridorName"].isin(['Blok M - Kota', 'Kalideres - Bundaran HI via Veteran','Matraman Baru - Ancol', 'Pinang Ranti - Pluit','Pulo Gadung - Monas','Pulo Gadung - Monas'])][['corridorID', 'corridorName']]
display(value_TJ.value_counts())
# Out:
# corridorID  corridorName
# 2           Pulo Gadung - Monas                    279
# 5           Matraman Baru - Ancol                  246
# 1           Blok M - Kota                          230
# M3          Kalideres - Bundaran HI via Veteran    204
# M9          Pinang Ranti - Pluit                   149
# 3           Kalideres - Bundaran HI via Veteran    127
# M1          Blok M - Kota                          61
# M2          Pulo Gadung - Monas                    60
# 9           Pinang Ranti - Pluit                   59
# M5          Matraman Baru - Ancol                  15
# Name: count, dtype: int64

# %% [markdown]
# Dapat dilihat bahwa value corridorName pada corridorID yang bernilai 2 sama dengan M2, 1 sama dengan M1, 3 sama dengan M3, 5 sama dengan M5, dan 9 sama dengan M9 <br>
# Sehingga dapat kita satukan menjadi 1 corridorID

# %%
#Proses mengganti M1 hingga M9 menjadi 1 hingga 9
Tj['corridorID'].replace('M1','1',inplace=True)
Tj['corridorID'].replace('M2','2',inplace=True)
Tj['corridorID'].replace('M3','3',inplace=True)
Tj['corridorID'].replace('M5','5',inplace=True)
Tj['corridorID'].replace('M9','9',inplace=True)

# %%
value_TJ = Tj[Tj["corridorName"].isin(['Blok M - Kota', 'Kalideres - Bundaran HI via Veteran','Matraman Baru - Ancol', 'Pinang Ranti - Pluit','Pulo Gadung - Monas','Pulo Gadung - Monas'])][['corridorID', 'corridorName']]
display(value_TJ.value_counts())
# Out:
# corridorID  corridorName
# 2           Pulo Gadung - Monas                    339
# 3           Kalideres - Bundaran HI via Veteran    331
# 1           Blok M - Kota                          291
# 5           Matraman Baru - Ancol                  261
# 9           Pinang Ranti - Pluit                   208
# Name: count, dtype: int64

# %% [markdown]
# setelah diganti tidak ada lagi M1, M2, M3, M5, dan M9 <br>

# %%
pengecekan= Tj.groupby('corridorName')['corridorID'] .nunique()
pengecekan[pengecekan>1]
# Out:
# Series([], Name: corridorID, dtype: int64)

# %% [markdown]
# Kita lakukan pengecekan ulang dimana sudah tidak ada value corridorName yang memiliki corridorID lebih dari 1 ID <br>
# Setelah melakukan perubahan pada anomali unique data, selanjunya kita lakukan cleaning data pada coloum corridorName dan corridorID

# %%
#melihat korelasi antara corridorID dan corridorName yang corridorIdnya NaN
Tj[['corridorID', 'corridorName']][Tj['corridorID'].isna()]
# Out:
#       corridorID                                  corridorName
# 7      NaN        NaN
# 120    NaN        NaN
# 240    NaN        NaN
# 250    NaN        NaN
# 257    NaN        NaN
# ...    ...        ...
# 37689  NaN        NaN
# 37727  NaN        NaN
# 37770  NaN        NaN
# 37797  NaN        Rusun Marunda - Terminal Terpadu Pulo Gebang
# 37838  NaN        NaN
#
# [1257 rows x 2 columns]

# %% [markdown]
# Terdapat corridorName dengan value "Rusun Marunda - Terminal Terpadu Pulo Gebang" yang memiliki nilai corridorID NaN <br>
# Selanjutnya kita akan mengeksplor lebih lanjut pada corridor "Rusun Marunda - Terminal Terpadu Pulo Gebang"

# %%
Tj.loc[(Tj['corridorName'] == 'Rusun Marunda - Terminal Terpadu Pulo Gebang') | (Tj['corridorID'].isna())  , ['corridorName', 'corridorID']]
# Out:
#                                        corridorName corridorID
# 7      NaN                                           NaN
# 120    NaN                                           NaN
# 206    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 230    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 240    NaN                                           NaN
# ...    ...                                           ...
# 37689  NaN                                           NaN
# 37727  NaN                                           NaN
# 37770  NaN                                           NaN
# 37797  Rusun Marunda - Terminal Terpadu Pulo Gebang  NaN
# 37838  NaN                                           NaN
#
# [1406 rows x 2 columns]

# %% [markdown]
# Kita dapat bahwa corridorName "Rusun Marunda - Terminal Terpadu Pulo Gebang"  memiliki corridorID "JAK.110A"

# %%
Tj[['corridorName', 'corridorID']][Tj['corridorName'].isna()]
# Out:
#       corridorName corridorID
# 7      NaN          NaN
# 38     NaN          5M
# 39     NaN          2
# 60     NaN          T21
# 61     NaN          12A
# ...    ...          ...
# 37792  NaN          S31
# 37815  NaN          JAK.56
# 37824  NaN          S21
# 37838  NaN          NaN
# 37885  NaN          3B
#
# [1930 rows x 2 columns]

# %% [markdown]
# Terdapat corridoID dengan value 5M, 2, T21, 12A, S31, JAK.56, S21, dan 3B yang memiliki nilai corridorName NaN <br>
# Selanjutnya kita akan mengeksplor lebih lanjut pada corridorID "2"

# %%
Tj.loc[(Tj['corridorID'] == '2') | (Tj['corridorName'].isna())  , ['corridorName', 'corridorID']]
# Out:
#               corridorName corridorID
# 7      NaN                  NaN
# 38     NaN                  5M
# 39     NaN                  2
# 48     Pulo Gadung - Monas  2
# 60     NaN                  T21
# ...    ...                  ...
# 37792  NaN                  S31
# 37815  NaN                  JAK.56
# 37824  NaN                  S21
# 37838  NaN                  NaN
# 37885  NaN                  3B
#
# [2269 rows x 2 columns]

# %% [markdown]
# Kita dapat bahwa corridorId "2" memiliki corridorName "Pulo Gadung-Monas"

# %%
Tj.loc[(Tj['corridorName'] == 'Rusun Marunda - Terminal Terpadu Pulo Gebang') | (Tj['corridorID'].isna()) & (Tj['corridorID']=='JAK.110A') , ['corridorName', 'corridorID']]
# Out:
#                                        corridorName corridorID
# 206    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 230    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 506    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 530    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 806    Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# ...                                             ...       ...
# 37332  Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 37518  Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 37532  Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 37623  Rusun Marunda - Terminal Terpadu Pulo Gebang  JAK.110A
# 37797  Rusun Marunda - Terminal Terpadu Pulo Gebang  NaN
#
# [150 rows x 2 columns]

# %% [markdown]
# Dapat dilihat bahwa terdapat value NaN pada coloum corridorID dengan value corridorName "Rusun Marunda - Terminal Terpadu Pulo Gebang", sehingga ini dapat menjadi acuan saya dalam mengisi nilai NaN tersebut

# %%
Tj.loc[(Tj['corridorID'] == '2') | (Tj['corridorName'].isna()) & ((Tj['corridorName']=='Pulo Gadung - Monas')), ['corridorName', 'corridorID']]
# Out:
#               corridorName corridorID
# 39     NaN                  2
# 48     Pulo Gadung - Monas  2
# 92     Pulo Gadung - Monas  2
# 339    Pulo Gadung - Monas  2
# 348    Pulo Gadung - Monas  2
# ...                    ... ..
# 36874  Pulo Gadung - Monas  2
# 37074  Pulo Gadung - Monas  2
# 37274  Pulo Gadung - Monas  2
# 37474  Pulo Gadung - Monas  2
# 37693  Pulo Gadung - Monas  2
#
# [345 rows x 2 columns]

# %% [markdown]
# Dapat dilihat bahwa terdapat value NaN pada coloum corridorName dengan value corridorID "2", sehingga ini dapat menjadi acuan saya dalam mengisi nilai NaN tersebut pada coloum corridorName

# %%
#Dilakukan korelasi amtara corridorID dan corridorName agar pengisian nilai NaN dapat sesuai antar kolom tersebut dengan methode ffil dan bfill yang disesuaikan 
Tj['corridorName'] = Tj.groupby('corridorID')['corridorName'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %% [markdown]
# Saya melakukan groupby antara coloum corridorID dan corridorName agar pengisian nilai NaN terkorelasi valuenya pada coloum corridorID dan corridorName

# %%
anomali = Tj.groupby('corridorName')['corridorID'].nunique()
anomali[anomali > 1]
# Out:
# Series([], Name: corridorID, dtype: int64)

# %% [markdown]
# Tidak terdapat anomali data pada corridorID dan corridorName

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          1257
# corridorName        1257
# direction           0
# tapInStops          1213
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %% [markdown]
# Dapat dilihat bahwa masih ada data bernilai NaN pada corridorID dan corridorName

# %%
plt.figure(figsize=(10,10))
sns.heatmap(Tj[['corridorID','corridorName', 'tapInStops', 'tapOutStops', 'payAmount']].isna())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.heatmap(Tj[['corridorID','corridorName']].isna())
# Out:
# <Axes: >

# %% [markdown]
# Dari sebaran data diatas dapat dilihat bahwa corridorID dan corridorName yang memiliki value NaN saling berkaitan antar coloumnya, sehingga hal ini tidak dapat diisikan dengan method ffill, dan jikalau kita tinjau dari sebaran value pada 'tapInStops', 'tapOutStops', dan 'payAmount' tidak dapat menjadi acuan dalam mengisi value pada coloum corridorID dan corridorName yang memiliki nilai value NaN <br>
# <br>
# sehingga saya memiih untuk melakukan drop pada sisa missing value coloum corridorID dan corridorName

# %%
Tj.dropna(subset=['corridorID'],inplace=True)

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          1175
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         2203
# tapOutStopsName     1292
# tapOutStopsLat      1292
# tapOutStopsLon      1292
# stopEndSeq          1292
# tapOutTime          1292
# payAmount           976
# dtype: int64

# %% [markdown]
# ## CLEARING DATA MISSING VALUE PADA COLOUM payAmount

# %% [markdown]
# Pada tahap ini saya akan menangani missing value pada coloum payAmount

# %%
#pengecekan nilai NaN pada coloum payAmount berdasarkan corridorName dan corridorID
Tj[['corridorName', 'corridorID', 'payAmount']][Tj['payAmount'].isna()]
# Out:
#                               corridorName corridorID  payAmount
# 11     BKN - Blok M                         M7B       NaN
# 76     Stasiun Tebet - Kampung Melayu       JAK.48B   NaN
# 97     Jelambar - Kota                      3H        NaN
# 169    BKN - Blok M                         M7B       NaN
# 198    Stasiun Tebet - Rusun Karet Tengsin  JAK.48A   NaN
# ...                                    ...      ...    ..
# 37661  BKN - Blok M                         M7B       NaN
# 37674  Stasiun Tebet - Rusun Karet Tengsin  JAK.48A   NaN
# 37741  Jelambar - Kota                      3H        NaN
# 37861  Tanah Abang - St. Gondangdia         M1H       NaN
# 37882  Stasiun Tebet - Kampung Melayu       JAK.48B   NaN
#
# [976 rows x 3 columns]

# %% [markdown]
# Dapat terlihat bahwa terdapat nilai NaN pada coloum payAmount dengan value pada coloum corridorName dan corridorId yang sama

# %%
payAmount_On_CorridorID = pd.crosstab(Tj['corridorID'], Tj['payAmount'])
payAmount_On_CorridorID
# Out:
# payAmount   0.0  3500.0  20000.0
# corridorID
# 1           0    299     0
# 10          0    101     0
# 10A         147  0       0
# 10B         139  0       0
# 10D         0    164     0
# ...         ... ..      ..
# S21         0    388     0
# S22         0    136     0
# S31         0    0       151
# T11         0    260     0
# T21         0    0       179
#
# [211 rows x 3 columns]

# %%
# melihat missing value pada payAmount berdasarkan corridorID dan corridorName
unique_corridorID = Tj[Tj['payAmount'].isna()]['corridorID'].unique()
unique_corridorName = Tj[Tj['payAmount'].isna()]['corridorName'].unique()

print(f"CorridorID dengan Missing PayAmount:\n {unique_corridorID}\n")
print(f" Corridor Names dengan Missing PayAmount:\n {unique_corridorName}")
# Out:
# CorridorID dengan Missing PayAmount:
#  ['M7B' 'JAK.48B' '3H' 'JAK.48A' 'M1H']
#
#  Corridor Names dengan Missing PayAmount:
#  ['BKN - Blok M' 'Stasiun Tebet - Kampung Melayu' 'Jelambar - Kota'
#  'Stasiun Tebet - Rusun Karet Tengsin' 'Tanah Abang - St. Gondangdia']

# %%
#melihat unique value corridorID yang memiliki nilai payAmount 20000
unique_corridor_ids = Tj.loc[Tj['payAmount'] == 20000, 'corridorID'].unique()
unique_corridor_ids
# Out:
# array(['1T', 'B14', 'T21', 'D32', 'S31', 'B13', 'D31', '1K', '6P', 'S12'],
#       dtype=object)

# %%
#melihat unique value corridorID yang memiliki nilai payAmount 0
unique_corridor_ids = Tj.loc[Tj['payAmount'] == 0, 'corridorID'].unique()
unique_corridor_ids
# Out:
# array(['JAK.18', 'JAK.46', 'JAK.88', 'JAK.16', 'JAK.02', '3B', 'BW9',
#        'JAK.15', 'JAK.112', 'JAK.43B', 'JAK.42', 'JAK.36', 'JAK.06',
#        'JAK.14', '3A', '3C', 'JAK.71', 'JAK.77', 'JAK.44', 'JAK.19',
#        'JAK.75', 'JAK.52', 'JAK.37', 'JAK.31', '11M', 'JAK.43C', '2F',
#        'JAK.117', 'JAK.49', 'JAK.20', 'JAK.118', 'JAK.27', '4E', 'JAK.13',
#        'JAK.84', '2H', 'JAK.08', 'JAK.23', 'JAK.07', 'JAK.22', 'JAK.115',
#        'JAK.21', 'JAK.26', 'JAK.64', 'JAK.47', '12C', 'JAK.01', 'JAK.120',
#        'JAK.85', '11N', 'JAK.10', '2E', 'JAK.41', 'JAK.86', '9F', '11P',
#        'JAK.73', 'JAK.32', 'JAK.50', 'JAK.29', 'JAK.45', 'JAK.110A',
#        'JAK.51', 'JAK.54', 'JAK.03', 'JAK.25', 'JAK.39', 'JAK.80',
#        'JAK.11', 'JAK.17', '11K', '10B', 'JAK.30', 'JAK.58', 'JAK.34',
#        '10A', 'JAK.72', 'JAK.74', 'JAK.40', 'JAK.60', 'JAK.56', 'JAK.59',
#        'JAK.113', 'JAK.04', '12F', 'JAK.61', 'JAK.24', '11C', 'JAK.35',
# ...

# %%
#melihat unique value corridorID yang memiliki nilai payAmount 3500
unique_corridor_ids = Tj.loc[Tj['payAmount'] == 3500, 'corridorID'].unique()
unique_corridor_ids
# Out:
# array(['5', '6C', 'R1A', '11D', '12', '1Q', '5M', '9A', '4', 'S22', '13',
#        '9E', '9', 'T11', '6V', '11Q', '11', '1C', '1', '7E', '1P', '7D',
#        '6H', '14', 'JIS3', '2', '6N', 'M11', '9N', '7P', '13B', 'M7',
#        '12A', '9D', 'M8', 'B21', '3', '8K', 'M10', '10D', 'B11', '8C',
#        '12B', '5D', '7A', '7Q', '1M', '5C', '6Q', '8E', '6M', 'L13E',
#        '12P', '1F', '13C', '4B', '7C', '2A', '8A', '1E', 'M4', '9H',
#        '13D', '5N', '6T', '5F', '3F', '2P', 'S21', 'M12', '1N', 'S11',
#        '6U', '10', '2B', '10K', '6A', '4F', '6B', '5B', 'M6', '8', '6D',
#        '1H', '4C', 'M13', '8D', '4D', '7', '9C', 'D21', 'D11', '8M', '1B',
#        '12H', '7F', '6', '10H', '3E', '1A', '2Q', '1R', '7B'],
#       dtype=object)

# %%
def pengisian_payAmount(row):
    if row['corridorID'] in ['1K', '1T', '6P', 'B13', 'B14', 'D31', 'D32', 'S12', 'S31', 'T21']:
        return 20000
    elif row['corridorID'] in ['10A', '10B', '11B', '11C', '11K', '11M', '11N', '11P', '12C', '12F', '2E', '2F', '2H', '3A', '3B', '3C', '4E', '9F', 'BW9', 'JAK']:
        return 0
    else:
        return 3500

# Mengisi nilai
Tj['payAmount'] = Tj.apply(lambda row: pengisian_payAmount(row) if pd.isna(row['payAmount']) else row['payAmount'], axis=1)

# %% [markdown]
# Dari data diatas bisa disimpulkan bahwa tidak bisa menggunakan function ffill(), maka diasumsikan berdasarkan data lapangan bahwa semuanya memiliki jurusannya menggunakan Transjakarta yang memiliki tarif 3500 kecuali yang memiliki `corridorID` berawalan 'JAK', yang berawalan dari 'JAK' itu merupakan tarif transjakarta yang bernilai 0 atau free , kita juga menlakukan pengecekan unque value pada corridorID dengan payAmount 0, 3500, dan 20000, setelah yakin dengan asumsi, nilai NaN pada payAmount akan direplace.

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          1175
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         2203
# tapOutStopsName     1292
# tapOutStopsLat      1292
# tapOutStopsLon      1292
# stopEndSeq          1292
# tapOutTime          1292
# payAmount           0
# dtype: int64

# %% [markdown]
# Dari data diatas dapat dilihat bahwa nilai NaN pada coloum payAmount telah hilang

# %% [markdown]
# ## CLEARING DATA MISSING VALUE PADA COLOUM tapInStops

# %% [markdown]
# Setelah melakukan celaring missing value pada coloum corridorID, corridorName, dan coloum payAmount, selanjutnya kita akan melakukan celaring pada coloum tapInStops, dimana pada coloum ini saya akan mengkorelasikan hubunhan dengan coloum tapInStopsName

# %% [markdown]
# Saya melakukan pengecekan anomali terlebih dahulu

# %%
anomali = Tj.groupby('tapInStopsName')['tapInStops'].nunique()
anomali[anomali > 1]
# Out:
# tapInStopsName
# Dukuh Atas 2    2
# Name: tapInStops, dtype: int64

# %% [markdown]
# Dapat dilihat bahwa tempat tapIn dengan nama dukuh atas memiliki nlai tapInStops lebih dari 1

# %%
# Pengecheckan unique pada 'tapOutStopsName'=='Dukuh Atas'
unique_tapInStops = Tj.loc[Tj['tapInStopsName'] == 'Dukuh Atas', 'tapInStops'].value_counts()
unique_tapInStops
# Out:
# tapInStops
# P00051    67
# Name: count, dtype: int64

# %% [markdown]
# Dukuh atas memiliki kode nilai tapInStops `P0051`, sedangkan pada pengecekan anomali didapat 2 nilai tapInstops, hal ini dapat menjadi suatu acuan bahwa nilai lainnya adalah NaN

# %%
Tj.loc[(Tj['tapInStopsName'] == 'Dukuh Atas') & (Tj['tapInStops'].isna()) , ['tapInStopsName', 'tapInStops']]
# Out:
#       tapInStopsName tapInStops
# 10042  Dukuh Atas     NaN
# 35364  Dukuh Atas     NaN

# %% [markdown]
# Terdapat nilai NaN pada tapInStopsName `Dukuh Atas`, sehingga saya menggunakan metode fillna dengan menghubungkan korelasi tapInStopsName dan coloum tapInStops dengan method ffill dan bfill

# %%
Tj['tapInStops'] = Tj.groupby('tapInStopsName')['tapInStops'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          35
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         2203
# tapOutStopsName     1292
# tapOutStopsLat      1292
# tapOutStopsLon      1292
# stopEndSeq          1292
# tapOutTime          1292
# payAmount           0
# dtype: int64

# %% [markdown]
# setelah kita lakukan pengisian nilai NaN dnegan method ffill, ternyata masih ada nilai NaN pada soloum tapInStops, mari kita analisis lebih lanjut coloum tersebut

# %%
#melihat persebaran nilai NaN sisa pada coloum tapInStops
Tj[[ 'tapInStopsName', 'tapInStopsLat','tapInStopsLon', 'tapInStops']][Tj['tapInStops'].isna()]
# Out:
#                         tapInStopsName  tapInStopsLat  tapInStopsLon  \
# 32155  PPKD Jaktim                     -6.247777       106.942360
# 32262  Rusun Pulo Gebang               -6.201478       106.949750
# 32365  Bundaran Alam Sutera 1          -6.244107       106.648890
# 32533  Graha Sindu Bpk Penabur         -6.159971       106.835090
# 32572  Rusun Rorotan 2                 -6.149932       106.954780
# 32663  Jln. Pinang 1                   -6.114470       106.903190
# 32768  Fatmawati 1                     -6.292571       106.797430
# 32821  Nifarro Park                    -6.263007       106.843320
# 32852  Ponpes Baitul Quran Al Ikhwan 1 -6.128812       106.964910
# 32861  Sbr. Jln. R. Anggun             -6.161055       106.769920
# 33093  Sbr. Jln. Rawabadung            -6.209004       106.922874
# 33296  Term. Muara Angke 2             -6.109001       106.773490
# 33300  Pusdiklat Pajak Jln. Sakti IV   -6.188239       106.784410
# ...

# %% [markdown]
# Dari Hasil diatas dapat dilihat bahwa nilai NaN pada coloum tapInStops tidak memiliki clue tambahan dari coloum lain bagaimana harus mengisi nilai missing tersebut, sehingga saya memutuskan untuk mengganti nilai sisa missing value tersebut dengan `-`, hal ini dikarenakan nilai tapInStops dapat diwakili oleh coloum tapInStopsName

# %%
#Mengganti nilai NaN sisa pada coloum tapInStops dengan -
Tj['tapInStops'].replace(np.nan,'-',inplace=True)

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          0
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         2203
# tapOutStopsName     1292
# tapOutStopsLat      1292
# tapOutStopsLon      1292
# stopEndSeq          1292
# tapOutTime          1292
# payAmount           0
# dtype: int64

# %% [markdown]
# ## Clearing Data Missing Value Pada Coloum tapOutStops, tapOutStopsName, tapOutStopsLat, tapOutStopsLon, stopEndSeq , tapOutTime

# %% [markdown]
# Pada tahap ini saya akan melakukan clearing missinng value pada coloum tapOutStops. pada clearing data coloum tapOutStops ini akan dilakukan dengan mengisi nilai NaN berdasarka coloum tapOutStopsName

# %%
anomali = Tj.groupby('tapOutStopsName')['tapOutStops'].nunique()
anomali[anomali > 1]
# Out:
# tapOutStopsName
# Dukuh Atas 2    2
# Name: tapOutStops, dtype: int64

# %%
Tj.query("tapOutStopsName in ['Dukuh Atas']")[['tapOutStopsName', 'tapOutStops']].value_counts()
# Out:
# tapOutStopsName  tapOutStops
# Dukuh Atas       P00051         48
# Name: count, dtype: int64

# %% [markdown]
# Dukuh atas memiliki kode nilai tapOutStops `P0051`, sedangkan pada pengecekan anomali didapat 2 nilai tapOutstops, hal ini dapat menjadi suatu acuan bahwa nilai lainnya adalah NaN

# %%
Tj.loc[(Tj['tapOutStopsName'] == 'Dukuh Atas') & (Tj['tapOutStops'].isna()) , ['tapOutStopsName', 'tapOutStops']]
# Out:
#       tapOutStopsName tapOutStops
# 26833  Dukuh Atas      NaN
# 33758  Dukuh Atas      NaN

# %%
Tj['tapOutStops'] = Tj.groupby('tapOutStopsName')['tapOutStops'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))

# %% [markdown]
# Terdapat nilai NaN pada tapOutStopsName `Dukuh Atas`, sehingga saya menggunakan metode fillna dengan menghubungkan korelasi tapInStopsName dan coloum tapInStops dengan method ffill dan bfill

# %% [markdown]
# Setelah itu kita akan menangani missing value pada coloum tapOutStopsName, tapOutStopsLat, tapOutStopsLon, stopEndSeq , tapOutTime

# %%
#Melihat sebaran missing value
plt.figure(figsize=(10,10))
sns.heatmap(Tj[['tapOutStops','tapOutStopsName','tapOutStopsLat','tapOutStopsLon','stopEndSeq','tapOutTime']].isna())
# Out:
# <Axes: >

# %% [markdown]
# Dari grafik heatmap diatas dapat dilihat bahwa semua coloum yang memiliki missing value saling berkaitan tiap coloumnya, sehingga hal ini menyebabkan kesulitan dalam melakukan pengisian missing value, dikarenakan tidak tersapat clue pengisian pada coloum tersebut. saya memutuskan untuk menhapus semua baris yang NaN pada coloum tersebut

# %%
Tj.dropna(subset=['tapOutStopsName'],inplace=True)

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          0
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         19
# tapOutStopsName     0
# tapOutStopsLat      0
# tapOutStopsLon      0
# stopEndSeq          0
# tapOutTime          0
# payAmount           0
# dtype: int64

# %% [markdown]
# Masih terdapat missing value pada coloum pada coloum tapOutStops, sehingga akan dianalisa lebih lanjut

# %%
#melihat persebaran nilai NaN sisa pada coloum tapOutStops
Tj[[ 'tapOutStopsName', 'tapOutStopsLat','tapOutStopsLon', 'tapOutStops']][Tj['tapOutStops'].isna()]
# Out:
#                        tapOutStopsName  tapOutStopsLat  tapOutStopsLon  \
# 32068  Jln. H. Yahya                   -6.230219        106.87122
# 32419  Sbr. Jl H Emuntipala I          -6.277035        106.87761
# 32570  Sbr. Ps. Pisang                 -6.207759        106.79233
# 32926  Exit Tol Veteran Bintaro        -6.262649        106.76654
# 32960  MIN 8 Srengseng Sawah           -6.335943        106.82628
# 33424  Masjid Al Waqof                 -6.110646        106.91733
# 33550  Sbr. Persada Purnawira Halim    -6.259198        106.88547
# 33961  Grha Intirub                    -6.265216        106.87599
# 34084  Jln. Timbul III                 -6.350411        106.80329
# 34120  SMAN 28                         -6.286109        106.83318
# 34130  Griya Galaxy 126                -6.283553        106.86431
# 34179  Permata Eksekutif 2             -6.216798        106.76524
# 34213  Jln. Siman Noar                 -6.300103        106.88072
# ...

# %% [markdown]
# Sama dengan penanganan missing value pada coloum tapInStops, dimana sisa missing valunya akan diganti dengan `"-"`, dikarenakan value pada tapOutStops masih dapat diwakilkan oleh coloum tapOutStopsName

# %%
Tj['tapOutStops'].replace(np.nan,'Other',inplace=True)

# %%
Tj.isna().sum()
# Out:
# transID             0
# payCardID           0
# payCardBank         0
# payCardName         0
# payCardSex          0
# payCardBirthDate    0
# corridorID          0
# corridorName        0
# direction           0
# tapInStops          0
# tapInStopsName      0
# tapInStopsLat       0
# tapInStopsLon       0
# stopStartSeq        0
# tapInTime           0
# tapOutStops         0
# tapOutStopsName     0
# tapOutStopsLat      0
# tapOutStopsLon      0
# stopEndSeq          0
# tapOutTime          0
# payAmount           0
# dtype: int64

# %% [markdown]
# Dapat dilihat bahwa pada data setiap coloum sudah tidak ada missing value

# %%
Tj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35351 entries, 0 to 37899
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transID           35351 non-null  object
#  1   payCardID         35351 non-null  int64
#  2   payCardBank       35351 non-null  object
#  3   payCardName       35351 non-null  object
#  4   payCardSex        35351 non-null  object
#  5   payCardBirthDate  35351 non-null  int64
#  6   corridorID        35351 non-null  object
#  7   corridorName      35351 non-null  object
#  8   direction         35351 non-null  float64
#  9   tapInStops        35351 non-null  object
#  10  tapInStopsName    35351 non-null  object
#  11  tapInStopsLat     35351 non-null  float64
#  12  tapInStopsLon     35351 non-null  float64
#  13  stopStartSeq      35351 non-null  int64
#  14  tapInTime         35351 non-null  object
#  15  tapOutStops       35351 non-null  object
# ...

# %% [markdown]
# Setelah melewati beragam proses data cleaning di atas, dapat di simpulkan bahwa dari ***37.900*** data mentah yang di dapat, saya melakukan cleaning dan menghasilkan sisa data ***35.351*** data yang sudah bersih dari anomali dan missing value. <br>
# <br>
# Secara umum cleaning dilakukan dengan 3 metode, yaitu metode pertama adalah dengan melakukan pengisian nilai NaN pada satu coloum dengan mempertimbangkan korelasi pada coloum lainnya, hal ini saya lakukan dengan metode fillna `ffill` dan `bfill` pada coloum corridorID, corridorName, tapInStops, dan tapOutStops <br>
# Metode yang kedua adalah pengisian nilai NaN pada coloum `payamount`, dimana saya membuat fungsi yang dapat mengsisi nilai payAmount berdasarkan corridorIDnya, dengan 3 jenis payAmount yaitu 0, 3500, 20000. <br>
# Metode ketiga adalah metode terakhir yang saya gunakan pada coloum yang tidak memiliki clue dalam pengisian sehingga saya lakukan penghapusan baris pada coloum tersebut

# %% [markdown]
# ## Penyesuaian Coloum dan Penyesuaian Tipe Data
# ---

# %% [markdown]
# Setelah melakukan cleaning data, saya melakukan beberapa adjustment pada data frame

# %%
Tj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35351 entries, 0 to 37899
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transID           35351 non-null  object
#  1   payCardID         35351 non-null  int64
#  2   payCardBank       35351 non-null  object
#  3   payCardName       35351 non-null  object
#  4   payCardSex        35351 non-null  object
#  5   payCardBirthDate  35351 non-null  int64
#  6   corridorID        35351 non-null  object
#  7   corridorName      35351 non-null  object
#  8   direction         35351 non-null  float64
#  9   tapInStops        35351 non-null  object
#  10  tapInStopsName    35351 non-null  object
#  11  tapInStopsLat     35351 non-null  float64
#  12  tapInStopsLon     35351 non-null  float64
#  13  stopStartSeq      35351 non-null  int64
#  14  tapInTime         35351 non-null  object
#  15  tapOutStops       35351 non-null  object
# ...

# %% [markdown]
# ## Merubah datatype dari tapInTime dan tapOutTime

# %% [markdown]
# Saya melakukan perubahan pada coloum tapInTime dan coloum tapOutTime menjadi type data time, dan menambahkan coloum baru TapinHour dan tapOutHour untuk mengetahu jam tap in dan tap out transjakarta

# %%
Tj['tapInTime'] = pd.to_datetime(Tj['tapInTime'])
Tj['tapOutTime'] = pd.to_datetime(Tj['tapOutTime'])
Tj['tapInHour'] = Tj['tapInTime'].dt.hour
Tj['tapOutHour'] = Tj['tapOutTime'].dt.hour
Tj['tapDay'] = Tj['tapInTime'].dt.dayofweek

# %%
# mengganti coloum tapDay dengan nama hari
Tj['tapDay'] = Tj['tapDay'].replace({0 : 'Senin', 1 : 'Selasa', 2 : 'Rabu', 3 : 'Kamis', 4 : 'Jumat', 5 : 'Sabtu', 6 : 'Minggu'})
Tj.head()
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB  180062659848800   emoney      Bajragin Usada   M
# 1  LGXO740D2N47GZ  4885331907664776  dki         Gandi Widodo     F
# 2  DJWR385V2U57TO  4996225095064169  dki         Emong Wastuti    F
# 3  JTUZ800U7C86EH  639099174703      flazz       Surya Wacana     F
# 4  VMLO535V7F95NJ  570928206772      flazz       Embuh Mardhiyah  M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0  2008              5          Matraman Baru - Ancol
# 1  1997              6C         Stasiun Tebet - Karet via Patra Kuningan
# 2  1992              R1A        Pantai Maju - Kota
# 3  1978              11D        Pulo Gebang - Pulo Gadung 2 via PIK
# 4  1982              12         Tanjung Priok - Pluit
#
#    direction tapInStops  ... tapOutStops        tapOutStopsName  \
# 0  1.0        P00142     ...  P00253      Tegalan
# ...

# %% [markdown]
# ## Merubah Datatype dari payAmount Menjadi Integer

# %%
Tj['payAmount'] = Tj['payAmount'].astype('int64')

# %% [markdown]
# Setelah mengubah datatype pada coloum payAmount, selanjutnya saya membuat coloum baru yaitu kategori dari pembayaran

# %%
def categorize_payamount(payAmount):
    if payAmount == 0 :
        return 'JakLingko'
    elif payAmount == 3500:
        return 'Transjakarta'
    elif payAmount == 20000:
        return 'RoyalTrans'
    else:
        return (payAmount)

Tj['TypeOfTransJakarta']=Tj['payAmount'].apply(categorize_payamount)

# %% [markdown]
# Terdapat 3 jenis armada berdasarkan jumlah yang dibayar, yaitu JakLingko dengan bayaran 0 atau free, Transjakarta Regular dengan tarif 3500, dan RoyalTrans dengan tarif 20000

# %%
Tj.head()
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB  180062659848800   emoney      Bajragin Usada   M
# 1  LGXO740D2N47GZ  4885331907664776  dki         Gandi Widodo     F
# 2  DJWR385V2U57TO  4996225095064169  dki         Emong Wastuti    F
# 3  JTUZ800U7C86EH  639099174703      flazz       Surya Wacana     F
# 4  VMLO535V7F95NJ  570928206772      flazz       Embuh Mardhiyah  M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0  2008              5          Matraman Baru - Ancol
# 1  1997              6C         Stasiun Tebet - Karet via Patra Kuningan
# 2  1992              R1A        Pantai Maju - Kota
# 3  1978              11D        Pulo Gebang - Pulo Gadung 2 via PIK
# 4  1982              12         Tanjung Priok - Pluit
#
#    direction tapInStops  ...        tapOutStopsName  tapOutStopsLat  \
# 0  1.0        P00142     ...  Tegalan               -6.203101
# ...

# %% [markdown]
# ## Menambahkan coloum durasi perjalanan

# %%
#Membuat durasiTrip dalam satuan menit
Tj['durationTrip']=((Tj['tapOutTime']-Tj['tapInTime']).dt.total_seconds()/60).round(2)

# %%
# Membuat kolom Trip Category
def categorize_trip_duration(durationTrip):
    if durationTrip < 20:
        return 'Very Short Trip'
    elif durationTrip >=20 and durationTrip < 60:
        return 'Short Trip'
    elif durationTrip >= 60 and durationTrip < 120 :
        return 'Medium Trip'
    else:
        return 'Long Trip'

Tj['DurationCategory'] = Tj['durationTrip'].apply(categorize_trip_duration)
Tj
# Out:
#               transID            payCardID payCardBank  \
# 0      EIIW227B8L34VB  180062659848800      emoney
# 1      LGXO740D2N47GZ  4885331907664776     dki
# 2      DJWR385V2U57TO  4996225095064169     dki
# 3      JTUZ800U7C86EH  639099174703         flazz
# 4      VMLO535V7F95NJ  570928206772         flazz
# ...               ...           ...           ...
# 37895  ZWEC949B8Q87QG  4685818286724028395  brizzi
# 37896  YHHK837P6Y95GN  6502902290603767     dki
# 37897  YXPP627N4G95HO  213159426675861      emoney
# 37898  RGVK175U2U98UV  377840859133591      emoney
# 37899  FMZZ963S4B68ZP  501862539795         flazz
#
#                   payCardName payCardSex  payCardBirthDate corridorID  \
# 0      Bajragin Usada          M          2008              5
# 1      Gandi Widodo            F          1997              6C
# 2      Emong Wastuti           F          1992              R1A
# 3      Surya Wacana            F          1978              11D
# ...

# %% [markdown]
# Saya membuat coloum DurationCategory agar dapat mengelompokkan jenis trip yang berlaku di tarnsjakarta sehingga dapat mempermudah analisa

# %% [markdown]
# ## Menambahkan Coloum Age dan AgeCategory

# %% [markdown]
# Pada tahap ini saya akan menambahkan coloum Age dengan cara mengkonversi umur padat tahun sekarang dikurangi tahun lahir pengguna payCard

# %%
Tj['Age']=2023-Tj['payCardBirthDate']

# %%
def category(x):
    if 0 < x <= 18 :
        return 'Pelajar'
    elif 18 < x <= 50  :
        return 'Pekerja'
    elif 50 < x <= 60 :
        return 'Pekerja Senior'
    elif x > 60 :
        return 'Lansia'
    
Tj['ageCategory']=Tj['Age'].apply(category)
display(Tj.head(),Tj.tail())
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB  180062659848800   emoney      Bajragin Usada   M
# 1  LGXO740D2N47GZ  4885331907664776  dki         Gandi Widodo     F
# 2  DJWR385V2U57TO  4996225095064169  dki         Emong Wastuti    F
# 3  JTUZ800U7C86EH  639099174703      flazz       Surya Wacana     F
# 4  VMLO535V7F95NJ  570928206772      flazz       Embuh Mardhiyah  M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0  2008              5          Matraman Baru - Ancol
# 1  1997              6C         Stasiun Tebet - Karet via Patra Kuningan
# 2  1992              R1A        Pantai Maju - Kota
# 3  1978              11D        Pulo Gebang - Pulo Gadung 2 via PIK
# 4  1982              12         Tanjung Priok - Pluit
#
#    direction tapInStops  ...          tapOutTime  payAmount  tapInHour  \
# 0  1.0        P00142     ... 2023-04-03 06:00:53  3500       5
# ...

# %%
Tj.query("ageCategory in ['Pelajar', 'Pekerja', 'Pekerja Senior', 'Lansia']")[['Age', 'ageCategory']].value_counts().sort_index()
# Out:
# Age  ageCategory
# 11   Pelajar        749
# 12   Pelajar        682
# 13   Pelajar        707
# 14   Pelajar        704
# 15   Pelajar        812
#                    ...
# 73   Lansia         1
# 74   Lansia         8
# 75   Lansia         77
# 76   Lansia         16
# 77   Lansia         110
# Name: count, Length: 67, dtype: int64

# %% [markdown]
# ## STATISTIKA DATA

# %%
#Statistika deskriptif setelah data cleaning pada kolom data type object
Tj.describe(include='object')
# Out:
#                transID payCardBank         payCardName payCardSex corridorID  \
# count   35351           35351       35351               35351      35351
# unique  35351           6           1975                2          216
# top     EIIW227B8L34VB  dki         Fathonah Saefullah  F          1T
# freq    1               17464       78                  18805      384
#
#                 corridorName tapInStops tapInStopsName tapOutStops  \
# count   35351                 35351      35351          35351
# unique  216                   2502       2532           2200
# top     Cibubur - Balai Kota  P00170     Penjaringan    P00016
# freq    384                   227        227            301
#
#        tapOutStopsName tapDay TypeOfTransJakarta DurationCategory ageCategory
# count   35351           35351  35351              35351            35351
# unique  2217            7      3                  4                4
# ...

# %%
# Statistika deskriptif setelah data cleaning pada kolom data type numerical
Tj.describe(exclude='object')
# Out:
#           payCardID  payCardBirthDate     direction  tapInStopsLat  \
# count  3.535100e+04  35351.000000      35351.000000  35351.000000
# mean   4.234583e+17  1990.141976       0.500467     -6.214896
# min    6.040368e+10  1946.000000       0.000000     -6.394973
# 25%    1.800407e+14  1982.000000       0.000000     -6.245863
# 50%    3.507503e+15  1990.000000       1.000000     -6.214587
# 75%    4.693230e+15  2001.000000       1.000000     -6.175528
# max    4.997694e+18  2012.000000       1.000000     -6.089429
# std    1.319631e+18  13.026610         0.500007      0.057868
#
#        tapInStopsLon  stopStartSeq                      tapInTime  \
# count  35351.000000   35351.000000  35351
# mean   106.841549     13.541116     2023-04-16 08:01:22.269186048
# min    106.614730     0.000000      2023-04-01 06:22:27
# 25%    106.803470     4.000000      2023-04-10 08:59:52
# 50%    106.834830     10.000000     2023-04-16 17:27:38
# ...

# %%
# Melihat Sebaran data atau Outlier
cek = Tj[['payCardID', 'payCardBirthDate','direction','tapInStopsLat', 'tapInStopsLon', 'stopStartSeq',
        'tapOutStopsLat','tapOutStopsLon','stopEndSeq','payAmount', 'Age', 'durationTrip']]
#Plotting boxplot 
plt.figure(figsize=(15, 15))
for i, column in enumerate(cek):
    plt.subplot(5, 3, i+1)
    sns.boxplot(data=Tj[column], orient='horizontal')
    plt.title( f'{column}')
    plt.xlabel(column)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Lalu melakukan *uji normalitas* dengan menggunakan **Kolmogorov-Smirnov Test** untuk menguji lebih detail apakah data terdistribusi normal atau tidak

# %%
from scipy.stats import kstest, norm
#Melakukan Uji Normalitas
list = []
for i in cek: 
    ks_statistic, pvalue = kstest(Tj[i], 'norm', args=(Tj[i].mean(), Tj[i].std()))
    
    if pvalue > 0.05:
        list.append([i, round(pvalue, 3), 'Distribusi Normal'])
    else:
        list.append([i, round(pvalue, 3), 'Distribusi Tidak Normal'])

pd.DataFrame(list, columns=['Nama Kolom', 'PVal', 'Jenis Distribusi'])
# Out:
#           Nama Kolom  PVal         Jenis Distribusi
# 0   payCardID         0.0   Distribusi Tidak Normal
# 1   payCardBirthDate  0.0   Distribusi Tidak Normal
# 2   direction         0.0   Distribusi Tidak Normal
# 3   tapInStopsLat     0.0   Distribusi Tidak Normal
# 4   tapInStopsLon     0.0   Distribusi Tidak Normal
# 5   stopStartSeq      0.0   Distribusi Tidak Normal
# 6   tapOutStopsLat    0.0   Distribusi Tidak Normal
# 7   tapOutStopsLon    0.0   Distribusi Tidak Normal
# 8   stopEndSeq        0.0   Distribusi Tidak Normal
# 9   payAmount         0.0   Distribusi Tidak Normal
# 10  Age               0.0   Distribusi Tidak Normal
# 11  durationTrip      0.0   Distribusi Tidak Normal

# %% [markdown]
# Dari Boxplot yang dihasilkan dapat dilihat bahwa terdapat outlier hampir di setiap coloum kecali coloum direction, Hal ini disebabkan semua data diatas memiliki skala pengukuran `Categorical`, kolom 'payCardID', 'payCardBirthDate', 'tapInStopsLat', 'tapInStopsLon', 'stopStartSeq', 'tapOutStopsLat', 'tapOutStopsLon', 'stopEndSeq', 'age', 'payAmount' termasuk pengukuran `Nominal`, dan kolom 'direction' termasuk pengukuran `Ordinal`. Kecuali kolom 'durationTirp', kolom tersebut termasuk skala pengukuran `Interval` <br>
# <br>
#  Penggunaan uji normalitas dengan `Kolmogorov-Smirnov Test` (KSTEST) karena data set  tergolong besar. Secara statistika, dapat disimpulkan bahwa 12 kolom numerikal tersebut memiliki data yang tidak terdistribusi dengan normal yang di tes dengan uji tes normalitas `Kolmogorov-Smirnov Test`, seluruh kolom tersebut menghasilkan p-value di bawah  5% yang berarti tolak H0 yang dimana berarti distribusi tidak normal

# %%
Tj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35351 entries, 0 to 37899
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transID             35351 non-null  object
#  1   payCardID           35351 non-null  int64
#  2   payCardBank         35351 non-null  object
#  3   payCardName         35351 non-null  object
#  4   payCardSex          35351 non-null  object
#  5   payCardBirthDate    35351 non-null  int64
#  6   corridorID          35351 non-null  object
#  7   corridorName        35351 non-null  object
#  8   direction           35351 non-null  float64
#  9   tapInStops          35351 non-null  object
#  10  tapInStopsName      35351 non-null  object
#  11  tapInStopsLat       35351 non-null  float64
#  12  tapInStopsLon       35351 non-null  float64
#  13  stopStartSeq        35351 non-null  int64
#  14  tapInTime           35351 non-null  datetime64[ns]
# ...

# %% [markdown]
# Setelah semua data celaning selesai export data ke excel

# %%
Tj.to_excel('Transjakarta(1).xlsx', index=False)

# %% [markdown]
# ## **Data Analysis**
# ---

# %% [markdown]
# Setelah dataset sudah clean dari *duplikasi, missing value, dan anomali*, kini masuk ke tahap analisis. Sesuai *problems dan goals*, analisis yang akan dibuat terbagi menjadi 4 jenis, yaitu <br>
# A. Corridor Dengan tingkat kesibukan tertinggi <br>
# B. Penggunaan type transjakarta berdasarkan kelompok umur <br>
# C. Corridor Dengan jumlah penumpang perempuan terbanyak<br>
# D. Jenis Payment yang paling banyak digunakan<br>

# %% [markdown]
# ## A. Corridor Dengan Tingkat Kesibukan Tertinggi

# %% [markdown]
# Pada segmen ini saya akan menganalisa corridorName dengan tingkat penggunaan terbanyak transjakarta, Halte dengan tapInStop terbanyak, halte dengan TapOutStop terbanyak, Pengguna Transjakarta dalam satu hari, pengguna transjakarta dalam satu minggu

# %% [markdown]
# 1. Tingkat Pengguna Transjakarta

# %%
pengguna = Tj[['corridorName', 'TypeOfTransJakarta']]
pengguna_counts = pengguna['TypeOfTransJakarta'].value_counts().reset_index()
pengguna_counts
# Out:
#   TypeOfTransJakarta  count
# 0  Transjakarta       18179
# 1  JakLingko          15527
# 2  RoyalTrans         1645

# %%
# Visualisasi dengan menggunakan perhitungan jumlah isi kolom `transType` berdasarkan unique nya sebagai dasar ploting pie chart
Tj['TypeOfTransJakarta'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.03,0.03,0.03))
plt.title('Persentase Pengguna Layanan PT. TransJakarta')
plt.ylabel('Persentase')
plt.show()

# %% [markdown]
# Dari tabel dan grafik diatas dapat dilihat bahwa pengguna layanan transjakarta banyak didominasi oleh layanan transjakarta regular dengan jumlah 18179 dengan 51,42%, lalu disusul oleh jakLingko dengan 15527 jumlah dengan persentase 43.92%, lalu yang terakhir adalah RoyalTrans dengan 4.65%

# %%
pengguna = Tj[['corridorName','TypeOfTransJakarta']].value_counts().reset_index(). head(10)
pengguna
# Out:
#                                   corridorName TypeOfTransJakarta  count
# 0  Cibubur - Balai Kota                         RoyalTrans         384
# 1  Ciputat - CSW                                Transjakarta       376
# 2  Harmoni - Jakarta International Stadium      Transjakarta       332
# 3  Pulo Gadung - Monas                          Transjakarta       330
# 4  Kampung Rambutan - Pondok Gede               JakLingko          327
# 5  Rusun Pondok Bambu - Walikota Jakarta Timur  JakLingko          323
# 6  Kalideres - Bundaran HI via Veteran          Transjakarta       322
# 7  Kebayoran Lama - Tanah Abang                 Transjakarta       321
# 8  Rusun Rawa Bebek - Kodamar                   JakLingko          307
# 9  BKN - Blok M                                 Transjakarta       298

# %%
corridor = Tj['corridorName'].value_counts().head(10)

plt.figure(figsize=(18, 8))
corridor.plot(kind='bar', color='blue')
plt.title('Corridor dengan Penggunaan Terbanyak')
plt.xlabel('Nama Corridor')
plt.ylabel('Count')
for i, v in enumerate(corridor):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Dapat dilihat dari grafik bahwa corridor denhan nama Cibubur-Balai Kota memiliki jumlah pengguna terbanyak dengan jumlah 384, lalu diikuti ciputat-CSW, Harmoni - Jakarta International Stadium, Pulo Gadung - Monas, Kampung Rambutan - Pondok Gede, Rusun Pondok Bambu - Walikota Jakarta Timur, Kalideres - Bundaran HI via Veteran, Kebayoran Lama - Tanah Abang, Rusun Rawa Bebek - Kodamar, BKN - Blok M

# %%
TJ = Tj[Tj['TypeOfTransJakarta'] == 'Transjakarta']['corridorName'].value_counts().head(5)
JL = Tj[Tj['TypeOfTransJakarta'] == 'JakLingko']['corridorName'].value_counts().head(5)
RT = Tj[Tj['TypeOfTransJakarta'] == 'RoyalTrans']['corridorName'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Distribusi TransJakarta Regular di Setiap Koridor')
plt.xlabel('CorridorName')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Distribusi jakLingko di Setiap Koridor')
plt.xlabel('CorridorName')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 3)
RT.plot(kind='bar', color='red')
plt.title('Distribusi RoyalTrans di Setiap Koridor')
plt.xlabel('CorridorName')
plt.ylabel('Count')
for i, v in enumerate(RT):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Dari grafik bar diatas dapat dilihat bahwa penumpang yang menggunakan layanan transportasi PT transjakarta terbanyak terdapat pada corridor ciputat-csw dengan tipe transjakartanya adalah `Royal Trans` dengan jumlah 384, kemudian disusul oleh mode transportasi `transjakarta` yang regular dengan jumlah 376, dan terakhir ada pada `jakLingko` dengan jumlah 327. pada grafik bar dapat ita lihat n=bahwa walaupun royal trans memiliki nilai korridor dengan jumlah tertingi, namun pada corridor lainnya nilainya mengalami penurunan yang sangat signifiant, hal ini berbeda pada mode transportasi transjakarta dan jakLingko yang pada corridor lainnya mengalami penurunan sedikit (tidak significant). hal ini senada dengan apa yang ada pada grafik pie chart tentang persentase penggunaan transportasi transjakarta dimana transjakarta menduduki peringkat pertama, lalu ada jakLingko, kemudian yang terakhir royal Trans

# %% [markdown]
# 2. Halte Dengan Tap In terbanyak

# %% [markdown]
# pada segmen ini saya akan melihat halte/tempat dari transjakarta yang memiliki tingkat tap in terbanyak

# %%
pengguna = Tj[['corridorName','tapInStops']].value_counts().reset_index()
pengguna
# Out:
#                                  corridorName tapInStops  count
# 0     Pinang Ranti - Pramuka                   P00064     159
# 1     Rusun Kapuk Muara - Penjaringan          B03277P    125
# 2     Rusun Kapuk Muara - Penjaringan          P00170     111
# 3     Harmoni - Jakarta International Stadium  B04789P    84
# 4     Cibubur - BKN                            B00248P    82
# ...             ...                                ...    ..
# 3551  PGC 1 - Ancol                            P00015     1
# 3552  PGC - Juanda                             P00297     1
# 3553  PGC - Juanda                             P00137     1
# 3554  PGC - Juanda                             P00086     1
# 3555  Pasar Minggu - Jagakarsa                 B04591P    1
#
# [3556 rows x 3 columns]

# %% [markdown]
# Dapat dilihat dari tabel bahwa corridor yang memiliki halte dengan Tap In terbanyak adalah Pinang Ranti - Pramuka dengan jumlah 159 dengan kode tapInStops adalah P00064, dan yang paling sedikit adalah corridor dengan nama Pasar Minggu - Jagakarsa dengan jumlah 1

# %%
TJ_filtered = Tj['tapInStopsName'].value_counts().head(5)

plt.figure(figsize=(18, 8))
TJ_filtered.plot(kind='bar', color='purple')
plt.title('Halte dengan Tap In terbanyak')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(TJ_filtered):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Dari grafik diatas dapat dilihat bahwa tap In terbanyak adalah tap in dengan nama penjaringan dengan jumlah tap sebanyak 227

# %%
TJ = Tj[Tj['TypeOfTransJakarta'] == 'Transjakarta']['tapInStopsName'].value_counts().head(5)
JL = Tj[Tj['TypeOfTransJakarta'] == 'JakLingko']['tapInStopsName'].value_counts().head(5)
RT = Tj[Tj['TypeOfTransJakarta'] == 'RoyalTrans']['tapInStopsName'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Distribusi TransJakarta Regular di Setiap Halte Naik Penumpang')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Distribusi jakLingko di Setiap Halte Naik Penumpang')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 3)
RT.plot(kind='bar', color='red')
plt.title('Distribusi RoyalTrans di Setiap Halte Naik Penumpang')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(RT):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Pada grafik diatas bisa disimpulkan bahwa pengguna `RoyalTrans` dan `TransJakarta` terbanyak saat naik di dominasi oleh halte di sekitar Jakarta Pusat dan Jakarta Selatan, hal ini bisa disebabkan karena disana daerah perkantoran di Jakarta, dan satu halte berada di Bintaro Xchange, hal itu bisa di sebabkan di daerah Bintaro menjadi daerah padat pemukiman suburban Jakarta. Selanjutnya di Transportasi Umum `Jak Lingko` didominasi oleh daerah Jakarta Timur dan Utara.

# %% [markdown]
# 3. Halte Dengan Tap Out terbanyak

# %%
pengguna = Tj[['corridorName','tapOutStops']].value_counts().reset_index()
pengguna
# Out:
#                                  corridorName tapOutStops  count
# 0     Rusun Kapuk Muara - Penjaringan          P00170      125
# 1     Pinang Ranti - Pramuka                   P00016      117
# 2     Rusun Kapuk Muara - Penjaringan          B03277P     111
# 3     Pinang Ranti - Pramuka                   P00179      100
# 4     Harmoni - Jakarta International Stadium  B01745P     97
# ...                                       ...      ...     ..
# 3179  Rawamangun - Tanah Merah                 B00170P     1
# 3180  Kebayoran Lama - Jelambar                B03253P     1
# 3181  Rawamangun - Klender                     B05477P     1
# 3182  Rawamangun - Klender                     B04706P     1
# 3183  Lebak Bulus - Ragunan                    B04900P     1
#
# [3184 rows x 3 columns]

# %% [markdown]
# Dapat dilihat dari tabel bahwa corridor yang memiliki halte dengan Tap In terbanyak adalah Rusun Kapuk Muara - Penjaringan dengan jumlah 159 dengan kode tapInStops adalah P00064, dan yang paling sedikit adalah corridor dengan nama Lebak Bulus - Ragunan dengan jumlah 1

# %%
TJ_filtered = Tj['tapOutStopsName'].value_counts().head(5)

plt.figure(figsize=(18, 8))
TJ_filtered.plot(kind='bar', color='yellow')
plt.title('Halte dengan Tap In terbanyak')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(TJ_filtered):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

# %% [markdown]
# Dari grafik diatas dapat dilihat bahwa tap In terbanyak adalah tap out dengan nama BKN dengan jumlah tap sebanyak 301

# %%
TJ = Tj[Tj['TypeOfTransJakarta'] == 'Transjakarta']['tapOutStopsName'].value_counts().head(5)
JL = Tj[Tj['TypeOfTransJakarta'] == 'JakLingko']['tapOutStopsName'].value_counts().head(5)
RT = Tj[Tj['TypeOfTransJakarta'] == 'RoyalTrans']['tapOutStopsName'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Distribusi TransJakarta Regular di Setiap Halte turun Penumpang')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Distribusi jakLingko di Setiap Halte turun Penumpang')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 3)
RT.plot(kind='bar', color='red')
plt.title('Distribusi RoyalTrans di Setiap Halte turun Penumpang')
plt.xlabel('Nama Halte')
plt.ylabel('Count')
for i, v in enumerate(RT):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Dari grafik diatas didapat bahwa penumpang `RoyalTrans` masih didominasi daerah Jakarta Selatan, dan sisanya ada diluar Jakarta seperti halte Bintaro Xchange dan Summarecon Bekasi, ini mengartikan bahwa yang menggunakan `RoyalTrans` tidak selalu diperuntukkan lintas antar kota. Tetapi pada penumpang `TransJakarta` didominasi turunnya penumpang di halte Jakarta Pusat, Selatan, dan Timur. Sedangkan untuk `Jak Lingko` masih didominasi turunnya penumpang di daerah Jakarta Utara dan Timur.

# %% [markdown]
# 4. Pengguna Transjakarta Dalam 1 Hari Berdasarkan Jam Tap In dan Jam Tap Out

# %%
grouped_data = Tj.groupby('tapInHour').size().reset_index(name='jumlah_trip')
all_hours = pd.DataFrame({'tapInHour': range(24)})

# Gabungkan data yang ada dengan semua jam
all_hours = pd.DataFrame({'tapInHour': range(24)})
grouped_data = all_hours.merge(grouped_data, on='tapInHour', how='left')
grouped_data['jumlah_trip'].fillna(0, inplace=True)
grouped_data = grouped_data.sort_values(by='tapInHour')

# Membuat line chart
plt.figure(figsize=(12, 6))
plt.plot(grouped_data['tapInHour'], grouped_data['jumlah_trip'], marker='o', color = 'blue', linestyle='-')
plt.xlabel('Jam')
plt.ylabel('Jumlah Trip')
plt.title('Jumlah Trip Berdasarkan Jam Turun Penumpang')
plt.xticks(range(24))
plt.grid()


for i, j in zip(grouped_data['tapInHour'], grouped_data['jumlah_trip']):
    plt.text(i, j, str(int(j)), ha='left', va='bottom', rotation='horizontal')

plt.show()

# %% [markdown]
# Berdasarkan grafik diatas didapat bahwa Transjakarta mengalami kenaikan penumpang pada pukul 5 - 6, dan pukul 15-17, dengan puncaknya pada pukul 05.00 dengan total 5433, hal ini diukur berdasarkan tap in yang dilakukan penumpang pada halte

# %%
grouped_data = Tj.groupby('tapOutHour').size().reset_index(name='jumlah_trip')
all_hours = pd.DataFrame({'tapOutHour': range(24)})

# Gabungkan data yang ada dengan semua jam
all_hours = pd.DataFrame({'tapOutHour': range(24)})
grouped_data = all_hours.merge(grouped_data, on='tapOutHour', how='left')
grouped_data['jumlah_trip'].fillna(0, inplace=True)
grouped_data = grouped_data.sort_values(by='tapOutHour')

# Membuat line chart
plt.figure(figsize=(12, 6))
plt.plot(grouped_data['tapOutHour'], grouped_data['jumlah_trip'], marker='o', color = 'red', linestyle='-')
plt.xlabel('Jam')
plt.ylabel('Jumlah Trip')
plt.title('Jumlah Trip Berdasarkan Jam Turun Penumpang')
plt.xticks(range(24))
plt.grid()


for i, j in zip(grouped_data['tapOutHour'], grouped_data['jumlah_trip']):
    plt.text(i, j, str(int(j)), ha='left', va='bottom', rotation='vertical')

plt.show()

# %% [markdown]
# Berdasarkan grafik diatas didapat bahwa Transjakarta mengalami kenaikan penumpang pada pukul 5 - 7, dan pukul 16-18, dengan puncaknya pada pukul 18.00 dengan total 4228, hal ini diukur berdasarkan tap out yang dilakukan penumpang pada halte

# %% [markdown]
# Dari dua grafik diatas dapat dilihat bahwa puncak penumpang yang melakukan tap in ada pada pagi hari yakni pukul 5, sedangkan puncak penumpang yang melakukan tap out ada pada sore hari yakni pukul 18.00, apabila kita melihat dan membandingkan kedua grafik kita dapat melihat bahwa terdapat perbedaan 1 jam antara nilai yang naik/ turun pada tap in dan tap out, hal ini dikarenakan batas jam mulai transjakrta dan batas akhir jam opersional transjkarta

# %% [markdown]
# 5. Pengguna Transjakarta Dalam seminggu

# %%
grouped_data = Tj.groupby('tapDay').size().reset_index(name='jumlah_trip')
grouped_data= grouped_data.sort_values(by= 'jumlah_trip',ascending=True)

# Membuat line chart
plt.figure(figsize=(8, 6))
plt.plot(grouped_data['tapDay'], grouped_data['jumlah_trip'], marker='o', linestyle='-')
plt.xlabel('Hari')
plt.ylabel('Jumlah Trip')
plt.title('Jumlah Trip Dalam Seminggu')
plt.grid()

# Menambahkan teks ke dalam plot
for i, j in zip(grouped_data['tapDay'], grouped_data['jumlah_trip']):
    plt.text(i, j, str(int(j)), ha='left', va='bottom', rotation='horizontal')

plt.show()

# %% [markdown]
# Dari grafik dapat dilihat bahwa trip/pelayanan Transjakarta paling banyak terjadi pada hari jumat yaitu sebesar 6417 trip, dimana pada hari minggu dan sabtu mengalami penurunan yang sangat siginifikan, dengan titik terendah adalah pada hari sabtu sebesar 1704 trip

# %%
TJ = Tj[Tj['TypeOfTransJakarta'] == 'Transjakarta']['tapDay'].value_counts()[['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu']]
JL = Tj[Tj['TypeOfTransJakarta'] == 'JakLingko']['tapDay'].value_counts()[['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu']]
RT = Tj[Tj['TypeOfTransJakarta'] == 'RoyalTrans']['tapDay'].value_counts()[['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu']]

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Jumlah Trip Transjakarta Dalam Seminggu')
plt.xlabel('Hari')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Jumlah Trip JakLingko Dalam Seminggu')
plt.xlabel('Hari')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 3)
RT.plot(kind='bar', color='red')
plt.title('Jumlah Trip Royal Trans Dalam Seminggu')
plt.xlabel('Hari')
plt.ylabel('Count')
for i, v in enumerate(RT):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Berdasarkan grafik bar diatas, `TransJakarta`, `Jak Lingko`, dan `Royal Trans`, ketiganya memiliki jumlah hari tersibuk yang sama yaitu senin sampai jumat dan mengalami penurunan pada sabtu dan minggu, dimana `TransJakarta`dan `Jak Lingko`, memiliki puncak hari tersibuk pada jumat dan kamis, sedangkan `Royal Trans` memiliki puncak hari tersibuk pada hari selasa dan jumat. Ini dapat disimpulkan bahwa pengguna Transportasi Umum PT. Transjakarta banyak digunakan pada **Weekday** dimana hari tersebut adalah hari kerja

# %% [markdown]
# 6. DURASI TRIP

# %%
Tj['DurationCategory'].value_counts().reset_index()
# Out:
#   DurationCategory  count
# 0  Medium Trip      21923
# 1  Short Trip       13194
# 2  Very Short Trip  123
# 3  Long Trip        111

# %%
Tj['DurationCategory'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.05, 0.05, 4, 4))
plt.title('Persentase Pengguna Layanan PT. TransJakarta')
plt.ylabel('Persentase')
plt.show()

# %%
categori = Tj['DurationCategory'].value_counts().reset_index()
plt.figure(figsize=(8, 8))
plt.barh(categori['DurationCategory'], categori['count'], color = 'green')
plt.xlabel('Kategori Trip')
plt.ylabel('Jumlah Trip')
plt.title('Jumlah Trip Per Kategori')

plt.show()

# %% [markdown]
# Dari grafik diatas didapat bahwa perjalanan dengan trip terbanyak ada pada medium trip dengan durasi perjalanan pada 1 hingga 2 jam

# %% [markdown]
# Selanjutnya saya membuat visualisasi grafik jumlah trip berdasarkan kategori trip dan juga jenis transjakarta yang digunakan

# %%
perjalanan = Tj.groupby(['DurationCategory', 'TypeOfTransJakarta']).size().reset_index(name='jumlah_trip')
perjalanan = perjalanan.sort_values(by='jumlah_trip', ascending=False)

plt.figure(figsize=(18, 18))
plt.barh(perjalanan['TypeOfTransJakarta'] + ' , ' + perjalanan['DurationCategory']  , perjalanan['jumlah_trip'], color = 'purple')
plt.xlabel('Jumlah Trip')
plt.ylabel('Durasi Trip - Kategori Transjakarta')
plt.title('Jumlah Trip Berdasarkan Durasi Trip dan Kategori Transjakarta (Diurutkan dari Terkecil)')

for i, v in enumerate(perjalanan['jumlah_trip']):
    plt.text(v + 10, i, str(v), va='center', fontsize=12)

# %% [markdown]
# Dari grafik diatas didapat bahwa jumlah trip tertinggi adalah medium trip dengan jenis transjakarta dengan jumlah 11183 dan yang terkecil adalah royal trans dengan durasi trip very short trip dengan jumlah 5. hal ini menunjukkan bahwa pengguna transjakarta menghabiskan durasi perjalanan antara 1 hingga 2 jam.

# %% [markdown]
# ## B. Penggunaan tipe transjakarta berdasarkan kelompok umur

# %% [markdown]
# Pada tahap ini saya akan melakukan analisa terkait jenis transjakarta yang paling sering digunakan berdasarkan kelompok umur dan kategorinya

# %% [markdown]
# 1. Distribusi Kelompok Usia Pengguna Layanan Transjakarta

# %%
umur = Tj['ageCategory'].value_counts().reset_index()
umur
# Out:
#       ageCategory  count
# 0  Pekerja         26190
# 1  Pelajar         5729
# 2  Pekerja Senior  2726
# 3  Lansia          706

# %%
Tj['ageCategory'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.05, 0.05, 0.05, 0.05))
plt.title('Persentase Pengguna Layanan PT. TransJakarta')
plt.ylabel('Persentase')
plt.show()

# %% [markdown]
# Dari tabel diatas dapat dilihat bahwa jumlah pekerja paling banyak dalam menggunakan transjakarta, dan jumlah paling sedkit ada pad kategoti umur lansia dengan jumlah 706. dari grafik dapat dilihat bahwa kelompok umur pekerja sangat bergantung dan sangat banyak dalam menggunakan mode transportasi transjakarta

# %% [markdown]
# 2. Pengguna Tipe Transjakarta

# %%
TJ = Tj[Tj['TypeOfTransJakarta'] == 'Transjakarta']['ageCategory'].value_counts().head(5)
JL = Tj[Tj['TypeOfTransJakarta'] == 'JakLingko']['ageCategory'].value_counts().head(5)
RT = Tj[Tj['TypeOfTransJakarta'] == 'RoyalTrans']['ageCategory'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Transjakarta')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Jaklingko')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 3)
RT.plot(kind='bar', color='red')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Royal Trans')
plt.ylabel('Count')
for i, v in enumerate(RT):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Dari grafik diatas dapat dilihat bahwa kategori umur pekerja mendominasi penggunaan pada semua jenis transjakarta, baik jaklingko, transjakarta regular, dan juga royal trans, pada grafik menunjukkan bahwa setelah pekerja diikuti oleh pelajar, lalu pekerja senior, dan terakhir lansia pada setiap mode transjakarta, jakLikngko, maupun Royal trans menunjukkan grafik yang sama. hal ini menunjukkan bahwa pengguna kelompok usia lansia yang menggunakan transjakarta paling kecil, hal ini dikarenakan batasan usia

# %% [markdown]
# 3. Kategori Durasi Perjalanan Berdasarkan Kategori Umur

# %%
perjalanan = Tj.groupby(['DurationCategory', 'ageCategory']).size().reset_index(name='jumlah_trip')
perjalanan = perjalanan.sort_values(by='jumlah_trip', ascending=True)

plt.figure(figsize=(18, 18))
plt.barh(perjalanan['ageCategory'] + ' , ' + perjalanan['DurationCategory']  , perjalanan['jumlah_trip'], color = 'Blue')
plt.xlabel('Jumlah Trip')
plt.ylabel('Durasi Trip - Kategori Umur')
plt.title('Jumlah Trip Berdasarkan Durasi Trip dan Kategori umur (Diurutkan dari Tebesar)')

for i, v in enumerate(perjalanan['jumlah_trip']):
    plt.text(v + 10, i, str(v), va='center', fontsize=12)

# %% [markdown]
# Dari Grafik diatas dapat dilihat bahwa pekerja dengan durasi perjalanan medium trip terbanyak dengan jumlah 16279, lalu yang paling kecil adalah lansia dengan durasi perjalanan long trip dengan jumlah 1

# %% [markdown]
# 4. Kategori gender yang menggunakan layanan transjakarta Berdasarkan Kategori Umur

# %%
plt.figure(figsize=(8,8)) 

# Menggunakan groupby untuk mengelompokkan berdasarkan 'ageCategory' dan 'payCardSex', dan menghitung ukuran setiap grup
grouped = Tj.groupby(['payCardSex', 'ageCategory']).size()

# Membuat pie chart dari Series yang diperoleh dari groupby dan size
explode = (0.05,) * len(grouped)
grouped.plot(kind='pie', autopct='%.2f%%', explode=explode)

# Mengatur judul dan label
plt.title('Persentase Gender Berdasarkan Kelompok Usia')
plt.ylabel('Persentase', labelpad=170)
plt.show()

# %% [markdown]
# Dari grafik diatas dapat dilihat bahwa pekerja perempuan memiliki persentase tertinggi dengan angka 39,83 %, dan yang paling kecil adalah lansia perempuan dengan angka 0,24 %

# %% [markdown]
# C. Corridor Dengan jumlah penumpang perempuan terbanyak

# %% [markdown]
# Pada segmen ini saya akan menganalisa terkait dengan gender yang spesifik tekait jumlah perempuan yang menggunakan layanan transjakarta

# %% [markdown]
# 1. Persentase perbandingan laki-laki dan wanita dalam menggunakan transjakarta

# %%
Tj['payCardSex'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.05, 0.05))
plt.title('Persentase Gender Pengguna Layanan PT. TransJakarta')
plt.ylabel('Persentase')
plt.show()

# %% [markdown]
# Dari grafik dapat dilihat bahwa perempuan lebih banyak yang menggunakan layanan transjakarta dengan angka 53.20% berdasarkan data transjakarta bulan april 2023

# %% [markdown]
# 2. Corridor Dengan Penumpang wanita terbanyak

# %%
pengguna = Tj[Tj['payCardSex'] == 'F']['corridorName'].value_counts().reset_index()

pengguna
# Out:
#                               corridorName  count
# 0    Pasar Minggu - Tanah Abang             217
# 1    Poris Plawad - Bundaran Senayan        213
# 2    Rusun Rawa Bebek - Kodamar             209
# 3    Terminal Tanah Merah - Pulo Gadung     196
# 4    Cilangkap - Cililitan                  195
# ..                     ...                  ...
# 211  Senen - Pulo Gadung                    5
# 212  Senen - Pulo Gadung via Kelapa Gading  5
# 213  Rawamangun - Tanah Merah               4
# 214  Cibubur - Kuningan                     4
# 215  Rusun Marunda - Rusun Waduk Pluit      4
#
# [216 rows x 2 columns]

# %%
TJ = Tj[Tj['payCardSex'] == 'F']['corridorName'].value_counts().head(5)
JL = Tj[Tj['payCardSex'] == 'M']['corridorName'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Female')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Male')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Dari tabel dan dari grafik dapat dilihat bahwa pengunjung perempuan pada corridor pasar minggu- Tanah Abang dengan jumlah 217, dan pada jenis kelamin laki-laki didapat bahwa corridor dengan jumlah terbanyak adalah ciputat-CSW denngan jumlah 252.

# %% [markdown]
# 3. Halte dengan Penumpang terbanyak berdasarkan gender dengan menganalisa tapInStops dan TapOutStops

# %%
# membuat analisa gender berdasarkan tapInStopsName
TJ = Tj[Tj['payCardSex'] == 'F']['tapInStopsName'].value_counts().head(5)
JL = Tj[Tj['payCardSex'] == 'M']['tapInStopsName'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Female')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Male')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Pada data transjakarta bulan april 2023, didapat bahwa jumlah tap in pada gender perempuan pada halte penjaringan memiliki nilai tertinggi dengan nilai 128, dan pada laki-laki pada halte Garuda Taman Mini dengan jumlah 116

# %%
TJ = Tj[Tj['payCardSex'] == 'F']['tapOutStopsName'].value_counts().head(5)
JL = Tj[Tj['payCardSex'] == 'M']['tapOutStopsName'].value_counts().head(5)

plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Female')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Pengguna Mode Layanan Transjakarta')
plt.xlabel('Male')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.tight_layout()

plt.show()

# %% [markdown]
# Pada data transjakarta bulan april 2023, didapat bahwa jumlah tap out pada gender perempuan pada halte BKN memiliki nilai tertinggi dengan nilai 151, dan pada laki-laki juga pada halte BKN dengan jumlah 150

# %% [markdown]
# 4. Persentase pengguna wanita dalam menggunakan angkutan umum PT. Transjakarta

# %%
plt.figure(figsize=(8,8)) 

# Menggunakan groupby untuk mengelompokkan berdasarkan 'TypeOfTransJakarta' dan 'payCardSex', dan menghitung ukuran setiap grup
grouped = Tj.groupby(['payCardSex', 'TypeOfTransJakarta']).size()

# Membuat pie chart dari Series yang diperoleh dari groupby dan size
explode = (0.08,) * len(grouped)
grouped.plot(kind='pie', autopct='%.2f%%', explode=explode)

# Mengatur judul dan label
plt.title('Persentase Gender Berdasarkan Kelompok Usia')
plt.ylabel('Persentase', labelpad=170)
plt.show()

# %% [markdown]
# Dari grafik pie chart diatas didapat bahwa penumpang perempuan memiliki persentase penumpang paling tinggi baik di moda transportasi transjkarta, Jaklingko, dan RoyalTrans. hal ini menandakan bahwa penumpang transjkarta banyak didominasi oleh perepmpuan, hal ini tentu menjadi pertimbangan khusus, agar penumpang perempuan merasa aman dan nyaman dalam menggunakan transjakarta

# %% [markdown]
# D. Jenis Payment yang paling banyak digunakan

# %% [markdown]
# 1. Persentase penggunaan payment Pada Pengguna Transjakarta

# %%
plt.figure(figsize=(6,6)) 
grouped = Tj.groupby(['payCardBank']).size()

# Membuat pie chart dari Series yang diperoleh dari groupby dan size
explode = (0.08,) * len(grouped)
grouped.plot(kind='pie', autopct='%.2f%%', explode=explode)

# Mengatur judul dan label
plt.title('Persentase Gender Berdasarkan Kelompok Usia')
plt.ylabel('Persentase', labelpad=17)
plt.show()

# %% [markdown]
# Dari grafik dapat dilihat bahwa pengguna kartu pembayaran tertinggi adalah kartu bank dki dengan nilai 49,40%, diketahui kartu yang paling banyak digunakan adalah dki yang berikutnya akan dijadikan sebuah rekomendasi Transjakarta untuk berkerja sama dengan dki.

# %% [markdown]
# 2. Penggunaan payment berdasarkan gender

# %%
TJ = Tj[Tj['payCardSex'] == 'F']['payCardBank'].value_counts().head(3)
JL = Tj[Tj['payCardSex'] == 'M']['payCardBank'].value_counts().head(3)


plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
TJ.plot(kind='bar', color='orange')
plt.title('Pengguna Payment Berdasarkan Gender')
plt.xlabel('Female')
plt.ylabel('Count')
for i, v in enumerate(TJ):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')

plt.subplot(1, 3, 2)
JL.plot(kind='bar', color='green')
plt.title('Pengguna Payment Berdasarkan Gender')
plt.xlabel('Male')
plt.ylabel('Count')
for i, v in enumerate(JL):
    plt.text(i, v + 1, str(v), ha='center', va='bottom')



plt.tight_layout()

plt.show()

# %% [markdown]
# Dapat dilihat bahwa bank dki masih mendominasi pada pembayaran transjakarta baik pada perempuan maupun laki-laki

# %% [markdown]
# 3. Penggunaan Payment Berdasarkan kelompok Usia

# %%
grouped = Tj.groupby(['payCardBank', 'ageCategory']).size()

# Membuat pie chart dari Series yang diperoleh dari groupby dan size
labels = grouped.index
sizes = grouped.values

plt.figure(figsize=(25, 25))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Persentase Pembayaran')
plt.show()

# %% [markdown]
# Dari grafik dapat dilihat bahwa Bank Dki pada kelompok pekerja, pelajar, pekerja senior maupun lansia menjadi yang paling populer digunakan dalam pembayaran transjakarta

# %% [markdown]
# ## **Kesimpulan dan Rekomendasi**
# ---

# %% [markdown]
# Berdasarkan analisis yang telah dilakukan pada dataset Transjakarta bulan April 2023, terdapat beberapa kesimpulan dan rekomendasi yang dapat diberikan kepada Transjakarta untuk meningkatkan efektivitas, efisiensi, dan profitabilitas operasinya:

# %% [markdown]
# ## KESIMPULAN

# %% [markdown]
# A. Corridor Dengan tingkat kesibukan tertinggi <br>
# 1.	Transjakarta adalah salah satu layanan dari PT Transjakarta, disbanding jaklingko dan RoyalTrans dengan persentase mencapai 51,42%, disusul oleh jaklingko diperingkat kedua dengan 43.92% dan royalTrans terakhir dengan 4.65%. Koridor Cibubur - Balai Kota adalah koridor yang paling banyak digunakan. Mungkin banyak dari pengguna Transjakarta yang tinggal di kawasan cibubur dan memili pekerjaan atau aktifitas di area Balai Kota.
# 2.	Halte penjaringan menjadi halte dengan jumlah tap in terbanyak, Dimana apabila kita memilah category transjakarta maka pada transjakarta halte terbanyak tap in adalah Garuda Taman Mini, pada Jak Lingko adalah Rusun Kapuk Muara, dan pada royal Trans adalah Gelora Bung karno 1, hal ini menunjukkan persebaran penumpang yang memilih menggunakan bus gratis ( jak Lingko), berbayar(3500= transjakarta), atau yang lebih mahal Royal Trans(20000).
# 3.	Dari grafik didapat bahwa penumpang yang melakukan Tap Out pada `RoyalTrans` masih didominasi daerah Jakarta Selatan, dan sisanya ada diluar Jakarta seperti halte Bintaro Xchange dan Summarecon Bekasi, ini mengartikan bahwa yang menggunakan `RoyalTrans` tidak selalu diperuntukkan lintas antar kota. Tetapi pada penumpang `TransJakarta` didominasi turunnya penumpang di halte Jakarta Pusat, Selatan, dan Timur. Sedangkan untuk `Jak Lingko` masih didominasi turunnya penumpang di daerah Jakarta Utara dan Timur.
# 4.	Puncak jam kesibukan pada semua jenis transjakarta  terjadi pada jam 5-6 pagi dan 4-6 sore. Hal ini dikarenakan jam-jam tersebut digunakan orang dalam berangkat bekerja, sekolah, dan aktifitas pagi lainnya, sedangkan pukul 4-6 sore adalah saat orang Kembali dari akfitasnya.
# 5.	Berdasarkan grafik harian, TransJakarta dan Jak Lingko yang memiliki jumlah penumpang terbanyak pertama dan edua, memiliki hari sibuk dari hari Senin sampai dengan Jumat dengan hari Jumat untuk transjakarta dan hari kamis untuk Jak Lingko sebagai hari puncak tersibuknya yang selanjutnya terjadi penurunan yang drastis di hari Sabtu dan Minggu. Lalu untuk `RoyalTrans` sama juga mendapati hari sibuk di hari Senin sampai Jumattetapi memiliki puncak tersibuk di hari Selasa dan Jumat. Ini dapat disimpulkan bahwa pengguna Transjakarta banyak pada hari weekday.
# 6.	Jenis perjalanan medium Trip adalah yang paling banyak dilakukan. Artinya mungkin mencerminkan perjalanan jarak menengah dengan waktu tempuh 1 sampai 2 jam yang dilakukan oleh warga Jakarta dalam kegiatan sehari-hari mereka. <br>
#
# B. Penggunaan type transjakarta berdasarkan kelompok umur <br>
# 1.	Kategori pekerja adalah kategori pengguna transjakarta terbanyak dengan jumlah 26190 dan dengan persentase 74.09%, sedangkan kategori lansia menjadi yang paling sedikit dengan jumlah 706 dan dengan persentase 2.00%
# 2.	Dari grafik diatas dapat dilihat bahwa kategori umur pekerja mendominasi penggunaan pada semua jenis transjakarta, baik jaklingko, transjakarta regular, dan juga royal trans, pada grafik menunjukkan bahwa setelah pekerja diikuti oleh pelajar, lalu pekerja senior, dan terakhir lansia pada setiap mode transjakarta, jakLikngko, maupun Royal trans menunjukkan grafik yang sama. hal ini menunjukkan bahwa pengguna kelompok usia lansia yang menggunakan transjakarta paling kecil, hal ini dikarenakan batasan usia dalam penggunaan transportasi public
# 3.	Kategori pekerja dengan durasi perjalanan 1 hingga 2 jam (medium trip) menjadi terbanyak dalam penggunaan transjakarta, hal ini menunjukkan bahwa pekerja banyak yang melakukan perjalanan yang tidak terlalu jauh, namu juga tidak dekat.
# 4.	Perempuan yang bekerja menjadi paling tinggi dalam penggunaan transjkarta, hal ini didasari karena mungkin banyak Perempuan yang tidak memiliki kendaraan pribadi, sehingga memilih menggunakan transportasi umum transjakarta <br>
#
# C. Corridor Dengan jumlah penumpang perempuan terbanyak<br>
# 1.	Dari grafik dapat dilihat bahwa perempuan lebih banyak yang menggunakan layanan transjakarta dengan angka 53.20% berdasarkan data transjakarta bulan april 2023.
# 2.	Dari tabel dan dari grafik dapat dilihat bahwa pengunjung perempuan pada corridor pasar minggu- Tanah Abang dengan jumlah 217, dan pada jenis kelamin laki-laki didapat bahwa corridor dengan jumlah terbanyak adalah ciputat-CSW denngan jumlah 252.
# 3.	Pada data transjakarta bulan april 2023, didapat bahwa jumlah tap in pada gender perempuan pada halte penjaringan memiliki nilai tertinggi dengan nilai 128, dan pada laki-laki pada halte Garuda Taman Mini dengan jumlah 116, Sedangkan  jumlah tap out pada gender perempuan pada halte BKN memiliki nilai tertinggi dengan nilai 151, dan pada laki-laki juga pada halte BKN dengan jumlah 150
# 4.	penumpang perempuan memiliki persentase penumpang paling tinggi baik di moda transportasi transjkarta, Jaklingko, dan RoyalTrans. hal ini menandakan bahwa penumpang transjkarta banyak didominasi oleh perepmpuan, hal ini tentu menjadi pertimbangan khusus, agar penumpang perempuan merasa aman dan nyaman dalam menggunakan transjakarta <br>
#
# D. Jenis Payment yang paling banyak digunakan<br>
# <br>
#     Kartu DKI adalah kartu yang paling banyak digunakan oleh pengguna Transjakarta, dengan persentase sebesar 49.2%. Bank DKI selaku penerbit Kartu DKI yang juga Bank Daerah dari Provinsi DKI Jakarta, tentunya sudah memberi kemudahan untuk pengguna Transjakarta dalam bertransaksi, dari hal tersebut wajar jika Kartu DKI sebagai kartu yang paling banyak digunakan

# %% [markdown]
# ## REKOMENDASI

# %% [markdown]
# 1. Meningkatkan fasilitas dan pelayanan pada corridor cibubur - balai kota, dalam hal ini dapat dilakukan peningkatan jumlah armada, dikarenakan corridor cibubur - balai kota adalah corridor dengan tingkat terpadat, maka ada kemungkinan pada peak hour menjadi corridor dengan jumlah penumpang terbanyak, hal ini akan berdampak pada wkatu tunggu penumpang, sehingga sangat direkomendasikan untuk dilakukan penambahan armada dan peningkatan fasilitas.
# 2. meningkatkan promosi Royal Trans, hal ini dikarenakan Royal Trans paling sedikit penumpangnya direkomendasikan pemberian diskon tarif, dikarenakan tarif yang diusung sangat berbeda jauh dengan transjakarta, perbedaan tarif yang signifikan juga menajdi pertimbangan masyarakat dalam memilih jenis transjkarta.
# 3. menambah armada transjkarta dan jak lingko pada hari weekdays dan pada pukul- pukul puncak penumpang, hal ini tentunya akan sangat membantu dalam mengurangi waktu tunggu penumpang, dan menhindari terjadinya penumpukan pada beberapa halte.
# 4. memberikan promosi pada kelompok umur pekerja, dikarenakan mereka adalaah yang paling banyak menggunakan transjakarta, hal ini akan sangat membantu mereka dalam penggunaan transjakarta.
# 5. meningkatkan armada khusus perempuan, dimana dapat dilihat bahwa jumlah penumpang yang menaiki transjakarta lebih banyak dibanding laki-laki, tentunya dengan memperbanyak armada transjakarta khusus perempuan akan sangat membantu perempuan dan menimbulkan rasa asam dan nyaman dalam menggunakan transjakarta
# 6. peningkatan kerjasama dengan bank selain DKI, direkomendasikan dengan memberikan promo atau diskon kepada pemegang kartu selain bank Dki, seperti mandiri, bri, atau bni sehingga nantinya akan lebih banyak lagi pengguna/nasabah bank tersebut

# %% [markdown]
# Dengan menerapkan rekomendasi-rekomendasi ini, diharapkan Transjakarta dapat mengoptimalkan layanannya dan memenuhi kebutuhan pengguna dengan lebih baik, yang kedepannya akan mendukung **efektivitas, efisiensi, dan profit** operasional Transjakarta sebagai transportasi publik.
